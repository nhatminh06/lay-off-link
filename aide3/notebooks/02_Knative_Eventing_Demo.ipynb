# %% [markdown]
# # AIDE 3 - Knative Eventing Demo
#
# Send a sample prediction request and inspect the emitted event behavior.

# %%
import requests

payload = {"features": [5.2, 3.1, 4.8, 1.6]}
resp = requests.post("http://localhost:8080/predict", json=payload, timeout=5)
resp.status_code, resp.json()
