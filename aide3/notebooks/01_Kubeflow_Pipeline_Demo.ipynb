# %% [markdown]
# # AIDE 3 - Kubeflow Pipeline Demo
#
# This notebook compiles the AIDE 3 Kubeflow pipeline definition.

# %%
from pathlib import Path
from aide3.kubeflow.pipeline import compile_pipeline

output_path = Path("../kubeflow/pipeline.yaml")
compiled = compile_pipeline(output_path=output_path)
compiled
